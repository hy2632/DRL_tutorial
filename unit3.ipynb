# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# For now we install this update of RL-Baselines3 Zoo
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
# Out:
# ^C

# %% [markdown]
# IF AND ONLY IF THE VERSION ABOVE DOES NOT EXIST ANYMORE. UNCOMMENT AND INSTALL THE ONE BELOW

# %%
# !pip install rl_zoo3==2.0.0a9
# Out:
# ^C

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Collecting rl_zoo3==2.0.0a9
#   Obtaining dependency information for rl_zoo3==2.0.0a9 from https://files.pythonhosted.org/packages/6a/dd/cc3fda55168bbe5bb944d7e1a311c219ae726e9c74eb84b60ae4d8d54556/rl_zoo3-2.0.0a9-py3-none-any.whl.metadata
#   Downloading rl_zoo3-2.0.0a9-py3-none-any.whl.metadata (1.3 kB)
# Collecting sb3-contrib>=2.0.0a9 (from rl_zoo3==2.0.0a9)
#   Obtaining dependency information for sb3-contrib>=2.0.0a9 from https://files.pythonhosted.org/packages/21/5b/882e97a1682af597a952a88cff9029582447f5467700aa5dd8a42de90903/sb3_contrib-2.0.0-py3-none-any.whl.metadata
#   Downloading sb3_contrib-2.0.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: gym==0.26.2 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from rl_zoo3==2.0.0a9) (0.26.2)
# Requirement already satisfied: huggingface-sb3>=2.2.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from rl_zoo3==2.0.0a9) (2.2.5)
# Requirement already satisfied: tqdm in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from rl_zoo3==2.0.0a9) (4.65.0)
# Collecting rich (from rl_zoo3==2.0.0a9)
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/8d/5f/21a93b2ec205f4b79853ff6e838e3c99064d5dbe85ec6b05967506f14af0/rich-13.5.2-py3-none-any.whl.metadata
#   Downloading rich-13.5.2-py3-none-any.whl.metadata (18 kB)
# Collecting optuna (from rl_zoo3==2.0.0a9)
#   Obtaining dependency information for optuna from https://files.pythonhosted.org/packages/69/60/87a06ef66b34cbe2f2eb0ab66f003664404a7f40c21403a69fad7e28a82b/optuna-3.3.0-py3-none-any.whl.metadata
#   Downloading optuna-3.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from rl_zoo3==2.0.0a9) (6.0)
# Collecting pytablewriter~=0.64 (from rl_zoo3==2.0.0a9)
#   Downloading pytablewriter-0.64.2-py3-none-any.whl (106 kB)
#      ------------------------------------ 106.6/106.6 kB 307.9 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (0.0.8)
# Requirement already satisfied: huggingface-hub~=0.8 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (0.15.1)
# Requirement already satisfied: wasabi in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (1.1.2)
# Requirement already satisfied: setuptools>=38.3.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (67.8.0)
# Collecting DataProperty<2,>=0.55.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Obtaining dependency information for DataProperty<2,>=0.55.0 from https://files.pythonhosted.org/packages/b1/3b/90ebd66ad57c588d6087e86e327436343e9cc60776a9445b79c6e80a022d/DataProperty-1.0.1-py3-none-any.whl.metadata
#   Downloading DataProperty-1.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Obtaining dependency information for mbstrdecoder<2,>=1.0.0 from https://files.pythonhosted.org/packages/c2/0f/726229136022b154895138bb10ba35e8435c4143f614cb5ad4d4e3fc21ec/mbstrdecoder-1.1.3-py3-none-any.whl.metadata
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathvalidate<3,>=2.3.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Collecting tabledata<2,>=1.3.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading tabledata-1.3.1-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading tcolorpy-0.1.3-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.2.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Obtaining dependency information for typepy[datetime]<2,>=1.2.0 from https://files.pythonhosted.org/packages/7f/31/0c7a66aa315cc8b2d1915fdd163283ba704307d7c0cf15b31e08c51aedba/typepy-1.3.1-py3-none-any.whl.metadata
#   Downloading typepy-1.3.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting stable-baselines3>=2.0.0 (from sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Obtaining dependency information for stable-baselines3>=2.0.0 from https://files.pythonhosted.org/packages/d9/57/13d4e4b7bbbc940815964ac31e205263b8133f1f2a0147bd4ca884a6e174/stable_baselines3-2.0.0-py3-none-any.whl.metadata
#   Downloading stable_baselines3-2.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting alembic>=1.5.0 (from optuna->rl_zoo3==2.0.0a9)
#   Obtaining dependency information for alembic>=1.5.0 from https://files.pythonhosted.org/packages/34/fe/eebb260c86c71d9ed861aa1434fc50601df657425b18329994af8c0bd789/alembic-1.11.2-py3-none-any.whl.metadata
#   Downloading alembic-1.11.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting cmaes>=0.10.0 (from optuna->rl_zoo3==2.0.0a9)
#   Obtaining dependency information for cmaes>=0.10.0 from https://files.pythonhosted.org/packages/f7/46/7d9544d453346f6c0c405916c95fdb653491ea2e9976cabb810ba2fe8cd4/cmaes-0.10.0-py3-none-any.whl.metadata
#   Downloading cmaes-0.10.0-py3-none-any.whl.metadata (19 kB)
# Collecting colorlog (from optuna->rl_zoo3==2.0.0a9)
#   Using cached colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from optuna->rl_zoo3==2.0.0a9) (23.1)
# Collecting sqlalchemy>=1.3.0 (from optuna->rl_zoo3==2.0.0a9)
#   Obtaining dependency information for sqlalchemy>=1.3.0 from https://files.pythonhosted.org/packages/71/41/eb74f55dfe9305736430051fc2a77d0479ff80d46aabd832dd583d242ad8/SQLAlchemy-2.0.19-cp310-cp310-win_amd64.whl.metadata
#   Downloading SQLAlchemy-2.0.19-cp310-cp310-win_amd64.whl.metadata (9.7 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->rl_zoo3==2.0.0a9)
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from rich->rl_zoo3==2.0.0a9) (2.15.1)
# Requirement already satisfied: colorama in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from tqdm->rl_zoo3==2.0.0a9) (0.4.6)
# Collecting Mako (from alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      -------------------------------------- 78.7/78.7 kB 257.3 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (4.5.0)
# Requirement already satisfied: filelock in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.9.0)
# Requirement already satisfied: fsspec in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2023.6.0)
# Requirement already satisfied: requests in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2.29.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.0.0a9)
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting chardet<6,>=3.0.4 (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Obtaining dependency information for chardet<6,>=3.0.4 from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna->rl_zoo3==2.0.0a9)
#   Downloading greenlet-2.0.2-cp310-cp310-win_amd64.whl (192 kB)
#      ------------------------------------ 192.2/192.2 kB 117.7 kB/s eta 0:00:00
# Requirement already satisfied: gymnasium==0.28.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (0.28.1)
# Requirement already satisfied: torch>=1.11 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.1.0.dev20230609)
# Requirement already satisfied: pandas in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.0.2)
# Requirement already satisfied: matplotlib in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.7.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (0.0.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: sympy in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.11.1)
# Requirement already satisfied: networkx in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.1.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from Mako->alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from pandas->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from sympy->torch>=1.11->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.2.1)
# Downloading rl_zoo3-2.0.0a9-py3-none-any.whl (76 kB)
#    ---------------------------------------- 76.1/76.1 kB 162.2 kB/s eta 0:00:00
# Downloading sb3_contrib-2.0.0-py3-none-any.whl (80 kB)
#    ---------------------------------------- 80.3/80.3 kB 186.8 kB/s eta 0:00:00
# Using cached optuna-3.3.0-py3-none-any.whl (404 kB)
# Using cached rich-13.5.2-py3-none-any.whl (239 kB)
# Using cached alembic-1.11.2-py3-none-any.whl (225 kB)
# Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Using cached DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Downloading SQLAlchemy-2.0.19-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 2.0/2.0 MB 104.7 kB/s eta 0:00:00
# Using cached stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached typepy-1.3.1-py3-none-any.whl (31 kB)
# Installing collected packages: tcolorpy, pathvalidate, mdurl, Mako, greenlet, colorlog, cmaes, chardet, sqlalchemy, mbstrdecoder, markdown-it-py, typepy, stable-baselines3, rich, alembic, sb3-contrib, optuna, DataProperty, tabledata, pytablewriter, rl_zoo3
#   Attempting uninstall: stable-baselines3
#     Found existing installation: stable-baselines3 2.0.0a5
#     Can't uninstall 'stable-baselines3'. No files were found to uninstall.
# Successfully installed DataProperty-1.0.1 Mako-1.2.4 alembic-1.11.2 chardet-5.2.0 cmaes-0.10.0 colorlog-6.7.0 greenlet-2.0.2 markdown-it-py-3.0.0 mbstrdecoder-1.1.3 mdurl-0.1.2 optuna-3.3.0 pathvalidate-2.5.2 pytablewriter-0.64.2 rich-13.5.2 rl_zoo3-2.0.0a9 sb3-contrib-2.0.0 sqlalchemy-2.0.19 stable-baselines3-2.0.0 tabledata-1.3.1 tcolorpy-0.1.3 typepy-1.3.1
# WARNING: Error parsing requirements for stable-baselines3: [Errno 2] No such file or directory: 'c:\\users\\hfy\\anaconda3\\envs\\drl\\lib\\site-packages\\stable_baselines3-2.0.0a5.dist-info\\METADATA'
#     WARNING: No metadata found in c:\users\hfy\anaconda3\envs\drl\lib\site-packages
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo (to revision update/hf) to c:\users\hfy\appdata\local\temp\pip-req-build-udskwy3w
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 7dcbff7e74e7a12c052452181ff353a4dbed313a
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting sb3-contrib>=2.0.0a9 (from rl-zoo3==2.0.0a9)
#   Obtaining dependency information for sb3-contrib>=2.0.0a9 from https://files.pythonhosted.org/packages/21/5b/882e97a1682af597a952a88cff9029582447f5467700aa5dd8a42de90903/sb3_contrib-2.0.0-py3-none-any.whl.metadata
#   Using cached sb3_contrib-2.0.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: gym==0.26.2 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from rl-zoo3==2.0.0a9) (0.26.2)
# Requirement already satisfied: huggingface-sb3>=2.2.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from rl-zoo3==2.0.0a9) (2.2.5)
# Requirement already satisfied: tqdm in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from rl-zoo3==2.0.0a9) (4.65.0)
# Collecting rich (from rl-zoo3==2.0.0a9)
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/8d/5f/21a93b2ec205f4b79853ff6e838e3c99064d5dbe85ec6b05967506f14af0/rich-13.5.2-py3-none-any.whl.metadata
#   Using cached rich-13.5.2-py3-none-any.whl.metadata (18 kB)
# Collecting optuna (from rl-zoo3==2.0.0a9)
#   Obtaining dependency information for optuna from https://files.pythonhosted.org/packages/69/60/87a06ef66b34cbe2f2eb0ab66f003664404a7f40c21403a69fad7e28a82b/optuna-3.3.0-py3-none-any.whl.metadata
#   Using cached optuna-3.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from rl-zoo3==2.0.0a9) (6.0)
# Collecting pytablewriter~=0.64 (from rl-zoo3==2.0.0a9)
#   Using cached pytablewriter-0.64.2-py3-none-any.whl (106 kB)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (0.0.8)
# Requirement already satisfied: huggingface-hub~=0.8 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (0.15.1)
# Requirement already satisfied: wasabi in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (1.1.2)
# Requirement already satisfied: setuptools>=38.3.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (67.8.0)
# Collecting DataProperty<2,>=0.55.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Obtaining dependency information for DataProperty<2,>=0.55.0 from https://files.pythonhosted.org/packages/b1/3b/90ebd66ad57c588d6087e86e327436343e9cc60776a9445b79c6e80a022d/DataProperty-1.0.1-py3-none-any.whl.metadata
#   Using cached DataProperty-1.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Obtaining dependency information for mbstrdecoder<2,>=1.0.0 from https://files.pythonhosted.org/packages/c2/0f/726229136022b154895138bb10ba35e8435c4143f614cb5ad4d4e3fc21ec/mbstrdecoder-1.1.3-py3-none-any.whl.metadata
#   Using cached mbstrdecoder-1.1.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathvalidate<3,>=2.3.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Using cached pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Collecting tabledata<2,>=1.3.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Using cached tabledata-1.3.1-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Using cached tcolorpy-0.1.3-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.2.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Obtaining dependency information for typepy[datetime]<2,>=1.2.0 from https://files.pythonhosted.org/packages/7f/31/0c7a66aa315cc8b2d1915fdd163283ba704307d7c0cf15b31e08c51aedba/typepy-1.3.1-py3-none-any.whl.metadata
#   Using cached typepy-1.3.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting stable-baselines3>=2.0.0 (from sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Obtaining dependency information for stable-baselines3>=2.0.0 from https://files.pythonhosted.org/packages/d9/57/13d4e4b7bbbc940815964ac31e205263b8133f1f2a0147bd4ca884a6e174/stable_baselines3-2.0.0-py3-none-any.whl.metadata
#   Using cached stable_baselines3-2.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting alembic>=1.5.0 (from optuna->rl-zoo3==2.0.0a9)
#   Obtaining dependency information for alembic>=1.5.0 from https://files.pythonhosted.org/packages/34/fe/eebb260c86c71d9ed861aa1434fc50601df657425b18329994af8c0bd789/alembic-1.11.2-py3-none-any.whl.metadata
#   Using cached alembic-1.11.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting cmaes>=0.10.0 (from optuna->rl-zoo3==2.0.0a9)
#   Obtaining dependency information for cmaes>=0.10.0 from https://files.pythonhosted.org/packages/f7/46/7d9544d453346f6c0c405916c95fdb653491ea2e9976cabb810ba2fe8cd4/cmaes-0.10.0-py3-none-any.whl.metadata
#   Using cached cmaes-0.10.0-py3-none-any.whl.metadata (19 kB)
# Collecting colorlog (from optuna->rl-zoo3==2.0.0a9)
#   Using cached colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from optuna->rl-zoo3==2.0.0a9) (23.1)
# Collecting sqlalchemy>=1.3.0 (from optuna->rl-zoo3==2.0.0a9)
#   Obtaining dependency information for sqlalchemy>=1.3.0 from https://files.pythonhosted.org/packages/71/41/eb74f55dfe9305736430051fc2a77d0479ff80d46aabd832dd583d242ad8/SQLAlchemy-2.0.19-cp310-cp310-win_amd64.whl.metadata
#   Using cached SQLAlchemy-2.0.19-cp310-cp310-win_amd64.whl.metadata (9.7 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->rl-zoo3==2.0.0a9)
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from rich->rl-zoo3==2.0.0a9) (2.15.1)
# Requirement already satisfied: colorama in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from tqdm->rl-zoo3==2.0.0a9) (0.4.6)
# Collecting Mako (from alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9)
#   Using cached Mako-1.2.4-py3-none-any.whl (78 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (4.5.0)
# Requirement already satisfied: filelock in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.9.0)
# Requirement already satisfied: fsspec in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2023.6.0)
# Requirement already satisfied: requests in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.29.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->rl-zoo3==2.0.0a9)
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting chardet<6,>=3.0.4 (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Obtaining dependency information for chardet<6,>=3.0.4 from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna->rl-zoo3==2.0.0a9)
#   Using cached greenlet-2.0.2-cp310-cp310-win_amd64.whl (192 kB)
# Requirement already satisfied: gymnasium==0.28.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (0.28.1)
# Requirement already satisfied: torch>=1.11 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.1.0.dev20230609)
# Requirement already satisfied: pandas in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.0.2)
# Requirement already satisfied: matplotlib in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.7.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (0.0.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: sympy in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.11.1)
# Requirement already satisfied: networkx in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from Mako->alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from matplotlib->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from pandas->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hfy\anaconda3\envs\drl\lib\site-packages (from sympy->torch>=1.11->stable-baselines3>=2.0.0->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.2.1)
# Using cached sb3_contrib-2.0.0-py3-none-any.whl (80 kB)
# Using cached optuna-3.3.0-py3-none-any.whl (404 kB)
# Using cached rich-13.5.2-py3-none-any.whl (239 kB)
# Using cached alembic-1.11.2-py3-none-any.whl (225 kB)
# Using cached cmaes-0.10.0-py3-none-any.whl (29 kB)
# Using cached DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Using cached SQLAlchemy-2.0.19-cp310-cp310-win_amd64.whl (2.0 MB)
# Using cached stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached typepy-1.3.1-py3-none-any.whl (31 kB)
# Building wheels for collected packages: rl-zoo3
#   Building wheel for rl-zoo3 (pyproject.toml): started
#   Building wheel for rl-zoo3 (pyproject.toml): finished with status 'done'
#   Created wheel for rl-zoo3: filename=rl_zoo3-2.0.0a9-py3-none-any.whl size=77007 sha256=a9bdce5b90eb883abc2b2b2882717d79edc0c82d2c8d96c7b8d35d36de560400
#   Stored in directory: C:\Users\HFY\AppData\Local\Temp\pip-ephem-wheel-cache-urhybs25\wheels\fc\36\d5\2ef574649d85327de098075c8523da50be2612f3e5807261f7
# Successfully built rl-zoo3
# Installing collected packages: tcolorpy, pathvalidate, mdurl, Mako, greenlet, colorlog, cmaes, chardet, sqlalchemy, mbstrdecoder, markdown-it-py, typepy, stable-baselines3, rich, alembic, sb3-contrib, optuna, DataProperty, tabledata, pytablewriter, rl-zoo3
#   Attempting uninstall: stable-baselines3
#     Found existing installation: stable-baselines3 2.0.0a5
#     Can't uninstall 'stable-baselines3'. No files were found to uninstall.
# Successfully installed DataProperty-1.0.1 Mako-1.2.4 alembic-1.11.2 chardet-5.2.0 cmaes-0.10.0 colorlog-6.7.0 greenlet-2.0.2 markdown-it-py-3.0.0 mbstrdecoder-1.1.3 mdurl-0.1.2 optuna-3.3.0 pathvalidate-2.5.2 pytablewriter-0.64.2 rich-13.5.2 rl-zoo3-2.0.0a9 sb3-contrib-2.0.0 sqlalchemy-2.0.19 stable-baselines3-2.0.0 tabledata-1.3.1 tcolorpy-0.1.3 typepy-1.3.1
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo 'C:\Users\HFY\AppData\Local\Temp\pip-req-build-udskwy3w'
#   Running command git checkout -b update/hf --track origin/update/hf
#   branch 'update/hf' set up to track 'origin/update/hf'.
#   Switched to a new branch 'update/hf'
#   Running command git submodule update --init --recursive -q
# WARNING: Error parsing requirements for stable-baselines3: [Errno 2] No such file or directory: 'c:\\users\\hfy\\anaconda3\\envs\\drl\\lib\\site-packages\\stable_baselines3-2.0.0a5.dist-info\\METADATA'
#     WARNING: No metadata found in c:\users\hfy\anaconda3\envs\drl\lib\site-packages

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e7
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# import rl_zoo3
from rl_zoo3.exp_manager import ExperimentManager

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c dqn.yml
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 2026624160
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.69e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1305     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 793      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1322     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1450     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1354     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1377     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1398     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3429     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 127      |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1409     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1406     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1412     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5364     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 125      |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1413     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1411     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1415     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1421     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1426     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1435     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1431     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10451    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1425     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 11208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1425     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1427     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1429     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1429     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1424     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 14225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1418     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1418     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 15766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1419     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 16596    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1418     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 17345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1418     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 17960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1419     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 18676    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1421     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 19336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1421     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 19874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1422     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 20339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1422     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 20853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1422     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 21407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1422     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 21855    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.775    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1422     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 22753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1423     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 23381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1423     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 24169    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1424     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 24963    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=144.00 +/- 96.97
# Episode length: 2187.00 +/- 790.21
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.19e+03 |
# |    mean_reward      | 144      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1000     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 25552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1007     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 26181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.736    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1013     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 26666    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1017     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 27049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.728    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1022     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 27518    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.72     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1030     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 28285    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1036     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 28790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1041     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 29363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.702    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1048     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 30081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1054     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 30849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1059     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 31310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1063     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 31850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1072     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 33017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.665    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1078     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 33803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1083     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 34522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1087     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 35175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.644    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1092     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 35911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1095     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 36324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1101     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 37168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.626    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1105     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 37782    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.617    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1112     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 38706    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.611    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1115     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 39320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1119     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 40047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1122     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 40598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1127     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 41490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1133     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 42399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1140     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 43472    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1145     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 44224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.554    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1149     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 45019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1152     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 45512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1155     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 46087    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.537    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1158     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 46741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1161     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 47242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1164     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 47861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1168     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 48616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.511    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1172     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 49398    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=209.00 +/- 111.24
# Episode length: 2341.00 +/- 1069.19
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.34e+03 |
# |    mean_reward      | 209      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1080     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 50066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1084     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 50718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1087     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 51326    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1090     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 51874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1094     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 52624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1097     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 53191    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.467    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1100     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 53804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1107     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 55056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1110     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 55663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1115     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 56633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.433    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1118     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 57247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.429    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1120     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 57719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1124     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 58476    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1128     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 59451    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1130     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 59877    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.398    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1135     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 60845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1137     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 61400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.388    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1139     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 61836    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1143     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 62746    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1145     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 63367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.367    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1147     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 63927    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.361    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1149     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 64545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1153     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 65434    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.348    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1155     |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 65874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.34     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1158     |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 66641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1162     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 67714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1165     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 68404    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.318    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1167     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 68920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.31     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1169     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 69710    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1173     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 70628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.291    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1176     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 71654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.28     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1180     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 72756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.273    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1182     |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 73398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.268    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1184     |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 73947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.261    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1186     |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 74650    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=239.00 +/- 51.52
# Episode length: 2762.20 +/- 621.63
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.76e+03 |
# |    mean_reward      | 239      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.257    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1097     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 75073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.251    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1099     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 75658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.243    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1102     |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 76488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1103     |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 76962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.23     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 1105     |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 77821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.223    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1107     |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 78458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.214    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1110     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 79350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.209    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1111     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 79890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.203    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1112     |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 80506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.195    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1115     |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 81348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.186    |
# | time/               |          |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 628      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3768     |
# |    fps              | 367      |
# |    time_elapsed     | 2589     |
# |    total_timesteps  | 950737   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 212684   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 630      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3772     |
# |    fps              | 367      |
# |    time_elapsed     | 2593     |
# |    total_timesteps  | 952045   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0274   |
# |    n_updates        | 213011   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 632      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3776     |
# |    fps              | 367      |
# |    time_elapsed     | 2598     |
# |    total_timesteps  | 954034   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 213508   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 636      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3780     |
# |    fps              | 367      |
# |    time_elapsed     | 2603     |
# |    total_timesteps  | 955785   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 213946   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 638      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3784     |
# |    fps              | 367      |
# |    time_elapsed     | 2606     |
# |    total_timesteps  | 957170   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 214292   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 642      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3788     |
# |    fps              | 367      |
# |    time_elapsed     | 2611     |
# |    total_timesteps  | 958782   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0205   |
# |    n_updates        | 214695   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 634      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3792     |
# |    fps              | 367      |
# |    time_elapsed     | 2616     |
# |    total_timesteps  | 960849   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00776  |
# |    n_updates        | 215212   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 632      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3796     |
# |    fps              | 367      |
# |    time_elapsed     | 2620     |
# |    total_timesteps  | 962290   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 215572   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 633      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3800     |
# |    fps              | 367      |
# |    time_elapsed     | 2624     |
# |    total_timesteps  | 963860   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 215964   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 624      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3804     |
# |    fps              | 367      |
# |    time_elapsed     | 2628     |
# |    total_timesteps  | 965593   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0331   |
# |    n_updates        | 216398   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 626      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3808     |
# |    fps              | 367      |
# |    time_elapsed     | 2635     |
# |    total_timesteps  | 967886   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 216971   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 626      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3812     |
# |    fps              | 367      |
# |    time_elapsed     | 2639     |
# |    total_timesteps  | 969544   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 217385   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 629      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3816     |
# |    fps              | 367      |
# |    time_elapsed     | 2643     |
# |    total_timesteps  | 970973   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00997  |
# |    n_updates        | 217743   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 633      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3820     |
# |    fps              | 367      |
# |    time_elapsed     | 2649     |
# |    total_timesteps  | 973462   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 218365   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | 636      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3824     |
# |    fps              | 367      |
# |    time_elapsed     | 2653     |
# |    total_timesteps  | 974945   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 218736   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=861.00 +/- 395.21
# Episode length: 6006.00 +/- 1898.10
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 6.01e+03 |
# |    mean_reward      | 861      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00812  |
# |    n_updates        | 218749   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 639      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 365      |
# |    time_elapsed     | 2672     |
# |    total_timesteps  | 977557   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0258   |
# |    n_updates        | 219389   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 632      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 365      |
# |    time_elapsed     | 2675     |
# |    total_timesteps  | 978663   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0298   |
# |    n_updates        | 219665   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 627      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3836     |
# |    fps              | 365      |
# |    time_elapsed     | 2679     |
# |    total_timesteps  | 980109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 220027   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 632      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3840     |
# |    fps              | 365      |
# |    time_elapsed     | 2686     |
# |    total_timesteps  | 982823   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 220705   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 631      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3844     |
# |    fps              | 365      |
# |    time_elapsed     | 2689     |
# |    total_timesteps  | 983959   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.031    |
# |    n_updates        | 220989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 628      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 365      |
# |    time_elapsed     | 2692     |
# |    total_timesteps  | 985292   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0449   |
# |    n_updates        | 221322   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 631      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 365      |
# |    time_elapsed     | 2698     |
# |    total_timesteps  | 987313   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 221828   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 630      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 365      |
# |    time_elapsed     | 2704     |
# |    total_timesteps  | 989474   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 222368   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | 634      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 365      |
# |    time_elapsed     | 2710     |
# |    total_timesteps  | 991756   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 222938   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 629      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 365      |
# |    time_elapsed     | 2716     |
# |    total_timesteps  | 994379   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.011    |
# |    n_updates        | 223594   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 631      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 366      |
# |    time_elapsed     | 2724     |
# |    total_timesteps  | 997110   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 224277   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | 628      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 366      |
# |    time_elapsed     | 2726     |
# |    total_timesteps  | 997954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 224488   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 615      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 366      |
# |    time_elapsed     | 2731     |
# |    total_timesteps  | 999746   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 224936   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=596.00 +/- 37.34
# Episode length: 3812.20 +/- 421.75
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.81e+03 |
# |    mean_reward      | 596      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00965  |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_6
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# Loading latest experiment, id=6
# Loading logs/dqn\SpaceInvadersNoFrameskip-v4_6\SpaceInvadersNoFrameskip-v4.zip
# Stacking 4 frames
# Atari Episode Score: 1395.00
# Atari Episode Length 7107
# Atari Episode Score: 515.00
# Atari Episode Length 4047
# Atari Episode Score: 600.00
# Atari Episode Length 4701
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga yaohuacn  -f logs/
# Out:
# Loading latest experiment, id=6
# Loading logs/dqn\SpaceInvadersNoFrameskip-v4_6\SpaceInvadersNoFrameskip-v4.zip
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to yaohuacn/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Saving model to: hub\dqn-SpaceInvadersNoFrameskip-v4\dqn-SpaceInvadersNoFrameskip-v4
# Saving video to C:\Users\HFY\AppData\Local\Temp\tmp21tjqjth\-step-0-to-step-1000.mp4
# Moviepy - Building video C:\Users\HFY\AppData\Local\Temp\tmp21tjqjth\-step-0-to-step-1000.mp4.
# Moviepy - Writing video C:\Users\HFY\AppData\Local\Temp\tmp21tjqjth\-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready C:\Users\HFY\AppData\Local\Temp\tmp21tjqjth\-step-0-to-step-1000.mp4
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/yaohuacn/dqn-SpaceInvadersNoFrameskip-v4
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Cloning https://huggingface.co/yaohuacn/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/yaohuacn/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
#
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip:   0%|          | 15.4k/26.0M [00:00<?, ?B/s]
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|██████████| 864/864 [00:00<?, ?B/s]
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0%|          | 17.4k/12.9M [00:00<?, ?B/s]
#
#
#
# Download file replay.mp4:   1%|▏         | 3.39k/249k [00:00<?, ?B/s]
#
#
#
#
# Download file train_eval_metrics.zip:  36%|███▋      | 8.19k/22.6k [00:00<?, ?B/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip:   5%|▍         | 1.20M/26.0M [00:01<00:21, 1.23MB/s]
#
#
#
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0%|          | 1.40k/12.9M [00:00<?, ?B/s]
#
#
#
#
# Download file train_eval_metrics.zip: 100%|██████████| 22.6k/22.6k [00:01<00:00, 14.6kB/s]
#
#
#
# Download file replay.mp4:  18%|█▊        | 45.4k/249k [00:01<00:04, 42.7kB/s]
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0%|          | 60.4k/12.9M [00:01<05:08, 43.6kB/s]
#
#
#
#
#
#
# Clean file train_eval_metrics.zip:   4%|▍         | 1.00k/22.6k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|██████████| 864/864 [00:00<?, ?B/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip:  21%|██▏       | 5.54M/26.0M [00:02<00:06, 3.17MB/s]
#
#
#
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   1%|          | 68.4k/12.9M [00:01<03:16, 68.3kB/s]
#
#
#
# Download file replay.mp4:  45%|████▌     | 113k/249k [00:02<00:02, 58.0kB/s]
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   3%|▎         | 339k/12.9M [00:02<01:11, 185kB/s]
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  21%|██        | 2.67M/12.9M [00:03<00:08, 1.21MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip:  30%|██▉       | 7.71M/26.0M [00:03<00:06, 2.76MB/s]
#
#
#
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  10%|▉         | 1.25M/12.9M [00:02<00:16, 755kB/s]
#
#
#
#
#
#
#
#
# Clean file replay.mp4:   0%|          | 1.00k/249k [00:00<?, ?B/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip:  37%|███▋      | 9.70M/26.0M [00:04<00:06, 2.49MB/s]
#
#
#
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  23%|██▎       | 2.93M/12.9M [00:03<00:08, 1.21MB/s]
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  31%|███       | 3.95M/12.9M [00:04<00:07, 1.26MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip:  44%|████▎     | 11.3M/26.0M [00:05<00:07, 2.19MB/s]
#
#
#
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  35%|███▍      | 4.46M/12.9M [00:04<00:06, 1.36MB/s]
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  46%|████▌     | 5.95M/12.9M [00:05<00:04, 1.56MB/s]
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  69%|██████▉   | 8.90M/12.9M [00:06<00:02, 2.07MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip:  55%|█████▍    | 14.2M/26.0M [00:06<00:04, 2.48MB/s]
#
#
#
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  60%|█████▉    | 7.67M/12.9M [00:05<00:02, 2.08MB/s]
#
#
#
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  77%|███████▋  | 9.89M/12.9M [00:06<00:01, 2.16MB/s]
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  82%|████████▏ | 10.6M/12.9M [00:07<00:01, 1.96MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip:  63%|██████▎   | 16.5M/26.0M [00:07<00:04, 2.43MB/s]
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0%|          | 1.00k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  99%|█████████▊| 12.7M/12.9M [00:07<00:00, 2.41MB/s]
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  14%|█▍        | 1.81M/12.9M [00:01<00:06, 1.88MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip:  77%|███████▋  | 19.9M/26.0M [00:08<00:02, 2.80MB/s]
#
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0%|          | 1.00k/12.9M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   9%|▉         | 1.16M/12.9M [00:01<00:10, 1.20MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip:  97%|█████████▋| 25.2M/26.0M [00:09<00:00, 3.64MB/s]
#
#
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4.zip:   0%|          | 1.00k/26.0M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4.zip:   6%|▌         | 1.56M/26.0M [00:01<00:15, 1.61MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|██████████| 26.0M/26.0M [00:11<00:00, 2.10MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|██████████| 26.0M/26.0M [00:11<00:00, 2.10MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|██████████| 26.0M/26.0M [00:11<00:00, 2.45MB/s]
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|██████████| 864/864 [00:11<?, ?B/s]
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|██████████| 864/864 [00:11<?, ?B/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|██████████| 864/864 [00:11<?, ?B/s]
#
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|██████████| 12.9M/12.9M [00:11<00:00, 1.07MB/s]
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|██████████| 12.9M/12.9M [00:11<00:00, 1.07MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|██████████| 12.9M/12.9M [00:11<00:00, 1.22MB/s]
#
#
#
#
# Download file replay.mp4: 100%|██████████| 249k/249k [00:11<00:00, 20.3kB/s]
#
#
#
# Download file replay.mp4: 100%|██████████| 249k/249k [00:11<00:00, 20.3kB/s]
# Download file replay.mp4: 100%|██████████| 249k/249k [00:11<00:00, 22.7kB/s]
#
#
#
#
#
# Download file train_eval_metrics.zip: 100%|██████████| 22.6k/22.6k [00:11<00:00, 14.6kB/s]
# Download file train_eval_metrics.zip: 100%|██████████| 22.6k/22.6k [00:11<00:00, 1.32kB/s]
#
#
#
#
#
#
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|██████████| 12.9M/12.9M [00:10<00:00, 2.41MB/s]
# Download file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|██████████| 12.9M/12.9M [00:10<00:00, 1.34MB/s]
#
#
#
#
#
#
#
# Clean file train_eval_metrics.zip: 100%|██████████| 22.6k/22.6k [00:10<00:00, 4.37kB/s]
#
#
#
#
#
#
# Clean file train_eval_metrics.zip: 100%|██████████| 22.6k/22.6k [00:10<00:00, 4.37kB/s]
# Clean file train_eval_metrics.zip: 100%|██████████| 22.6k/22.6k [00:10<00:00, 2.19kB/s]
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|██████████| 864/864 [00:10<?, ?B/s]
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|██████████| 864/864 [00:10<?, ?B/s]
# Clean file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|██████████| 864/864 [00:10<?, ?B/s]
#
#
#
#
#
#
#
#
#
# Clean file replay.mp4: 100%|██████████| 249k/249k [00:08<00:00, 31.4kB/s]
#
#
#
#
#
#
#
#
# Clean file replay.mp4: 100%|██████████| 249k/249k [00:08<00:00, 31.4kB/s]
# Clean file replay.mp4: 100%|██████████| 249k/249k [00:08<00:00, 31.4kB/s]
#
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|██████████| 12.9M/12.9M [00:04<00:00, 3.45MB/s]
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|██████████| 12.9M/12.9M [00:04<00:00, 3.45MB/s]
# Clean file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|██████████| 12.9M/12.9M [00:04<00:00, 3.33MB/s]
#
#
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|██████████| 12.9M/12.9M [00:03<00:00, 4.79MB/s]
#
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|██████████| 12.9M/12.9M [00:03<00:00, 4.79MB/s]
# Clean file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|██████████| 12.9M/12.9M [00:03<00:00, 4.44MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|██████████| 26.0M/26.0M [00:02<00:00, 15.5MB/s]
#
#
#
#
#
#
#
#
#
#
#
# Clean file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|██████████| 26.0M/26.0M [00:02<00:00, 15.5MB/s]
# Clean file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|██████████| 26.0M/26.0M [00:02<00:00, 13.4MB/s]
# c:\Users\HFY\anaconda3\envs\drl\lib\site-packages\gymnasium\utils\passive_env_checker.py:364: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
#
# t:   0%|          | 0/1002 [00:00<?, ?it/s, now=None]
# t:  15%|█▍        | 146/1002 [00:00<00:00, 1452.07it/s, now=None]
# t:  64%|██████▍   | 646/1002 [00:00<00:00, 3515.90it/s, now=None]
#
# ffmpeg version 6.0-essentials_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-libass --enable-libfreetype --enable-libfribidi --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libmfx --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'C:\Users\HFY\AppData\Local\Temp\tmp21tjqjth\-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.40, start: 0.000000, bitrate: 58 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 160x210, 56 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 00000172f0b9c0c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 00000172f0b9c0c0] profile High, level 1.2, 4:2:0, 8-bit
# [libx264 @ 00000172f0b9c0c0] 264 - core 164 r3106 eaa68fa - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=7 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'hub\dqn-SpaceInvadersNoFrameskip-v4\replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 160x210, q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=-577014:32:22.77 bitrate=  -0.0kbits/s speed=N/A
# frame= 1002 fps=0.0 q=-1.0 Lsize=     233kB time=00:00:33.30 bitrate=  57.4kbits/s speed= 157x
# video:222kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.935275%
# [libx264 @ 00000172f0b9c0c0] frame I:5     Avg QP:17.75  size:  3673
# [libx264 @ 00000172f0b9c0c0] frame P:479   Avg QP:22.28  size:   381
# [libx264 @ 00000172f0b9c0c0] frame B:518   Avg QP:29.54  size:    50
# [libx264 @ 00000172f0b9c0c0] consecutive B-frames: 25.6% 12.4% 11.7% 50.3%
# [libx264 @ 00000172f0b9c0c0] mb I  I16..4: 27.9% 26.1% 46.0%
# [libx264 @ 00000172f0b9c0c0] mb P  I16..4:  0.6%  0.9%  0.9%  P16..4:  7.4%  3.0%  1.9%  0.0%  0.0%    skip:85.2%
# [libx264 @ 00000172f0b9c0c0] mb B  I16..4:  0.2%  0.1%  0.1%  B16..8: 10.0%  0.9%  0.1%  direct: 0.2%  skip:88.6%  L0:48.5% L1:51.2% BI: 0.4%
# [libx264 @ 00000172f0b9c0c0] 8x8 transform intra:34.4% inter:5.4%
# [libx264 @ 00000172f0b9c0c0] coded y,uvDC,uvAC intra: 24.9% 40.8% 38.2% inter: 1.6% 2.1% 1.7%
# [libx264 @ 00000172f0b9c0c0] i16 v,h,dc,p: 49% 44%  6%  0%
# [libx264 @ 00000172f0b9c0c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 10% 68%  1%  0%  0%  0%  0%  0%
# [libx264 @ 00000172f0b9c0c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 13% 41%  2%  2%  3%  1%  2%  2%
# [libx264 @ 00000172f0b9c0c0] i8c dc,h,v,p: 53% 31% 15%  1%
# [libx264 @ 00000172f0b9c0c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 00000172f0b9c0c0] ref P L0: 75.8%  6.0% 10.6%  7.6%
# [libx264 @ 00000172f0b9c0c0] ref B L0: 80.8% 15.3%  3.9%
# [libx264 @ 00000172f0b9c0c0] ref B L1: 96.2%  3.8%
# [libx264 @ 00000172f0b9c0c0] kb/s:54.40
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   0%|          | 1.00/26.0M [00:00<?, ?B/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0%|          | 1.00/12.9M [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0%|          | 1.00/12.9M [00:00<?, ?B/s]
#
#
#
# Upload file replay.mp4:   0%|          | 1.00/233k [00:00<?, ?B/s]
#
#
#
#
# Upload file train_eval_metrics.zip:   0%|          | 1.00/35.0k [00:00<?, ?B/s]
#
#
#
#
# Upload file train_eval_metrics.zip: 15.3MB [00:01, 15.9MB/s]
#
#
#
# Upload file replay.mp4: 15.3MB [00:02, 7.97MB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 15.3MB [00:05, 3.18MB/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 15.3MB [00:05, 3.18MB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  59%|█████▉    | 15.3M/26.0M [00:06<00:04, 2.65MB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 30.5MB [00:08, 4.35MB/s]                            To https://huggingface.co/yaohuacn/dqn-SpaceInvadersNoFrameskip-v4
#    8169a4e..ab75e6f  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/yaohuacn/dqn-SpaceInvadersNoFrameskip-v4
#    8169a4e..ab75e6f  main -> main
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|██████████| 26.0M/26.0M [00:09<00:00, 4.35MB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|██████████| 26.0M/26.0M [00:09<00:00, 3.00MB/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|██████████| 12.9M/12.9M [00:09<00:00, 3.18MB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|██████████| 12.9M/12.9M [00:09<00:00, 1.49MB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|██████████| 12.9M/12.9M [00:09<00:00, 3.18MB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|██████████| 12.9M/12.9M [00:09<00:00, 1.49MB/s]
#
#
#
#
# Upload file replay.mp4: 100%|██████████| 233k/233k [00:09<00:00, 7.97MB/s]
# Upload file replay.mp4: 100%|██████████| 233k/233k [00:09<00:00, 26.3kB/s]
#
#
#
#
#
# Upload file train_eval_metrics.zip: 100%|██████████| 35.0k/35.0k [00:09<00:00, 15.9MB/s]
# Upload file train_eval_metrics.zip: 100%|██████████| 35.0k/35.0k [00:09<00:00, 3.95kB/s]

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/
# Out:
# Downloading from https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# No normalization file
# Saving to rl_trained/dqn\BeamRiderNoFrameskip-v4_1
# Downloading (…)erNoFrameskip-v4.zip:   0%|          | 0.00/27.2M [00:00<?, ?B/s]
# Downloading (…)erNoFrameskip-v4.zip:  38%|███▊      | 10.5M/27.2M [00:02<00:04, 3.97MB/s]
# Downloading (…)erNoFrameskip-v4.zip:  77%|███████▋  | 21.0M/27.2M [00:03<00:01, 5.82MB/s]
# Downloading (…)erNoFrameskip-v4.zip: 100%|██████████| 27.2M/27.2M [00:04<00:00, 5.98MB/s]
# Downloading (…)erNoFrameskip-v4.zip: 100%|██████████| 27.2M/27.2M [00:04<00:00, 5.62MB/s]
# c:\Users\HFY\anaconda3\envs\drl\lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\HFY\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
#
# Downloading (…)olve/main/config.yml:   0%|          | 0.00/548 [00:00<?, ?B/s]
# Downloading (…)olve/main/config.yml: 100%|██████████| 548/548 [00:00<?, ?B/s]
#
# Downloading (…)esolve/main/args.yml:   0%|          | 0.00/887 [00:00<?, ?B/s]
# Downloading (…)esolve/main/args.yml: 100%|██████████| 887/887 [00:00<?, ?B/s]
#
# Downloading (…)/main/env_kwargs.yml:   0%|          | 0.00/3.00 [00:00<?, ?B/s]
# Downloading (…)/main/env_kwargs.yml: 100%|██████████| 3.00/3.00 [00:00<?, ?B/s]
#
# Downloading train_eval_metrics.zip:   0%|          | 0.00/244k [00:00<?, ?B/s]
# Downloading train_eval_metrics.zip: 100%|██████████| 244k/244k [00:00<00:00, 781kB/s]
# Downloading train_eval_metrics.zip: 100%|██████████| 244k/244k [00:00<00:00, 779kB/s]

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render
# Out:
# Loading latest experiment, id=1
# Loading rl_trained/dqn\BeamRiderNoFrameskip-v4_1\BeamRiderNoFrameskip-v4.zip
# Stacking 4 frames
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# c:\Users\HFY\anaconda3\envs\drl\lib\site-packages\stable_baselines3\common\save_util.py:166: UserWarning: Could not deserialize object exploration_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: 'bytes' object cannot be interpreted as an integer
#   warnings.warn(
# c:\Users\HFY\anaconda3\envs\drl\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
